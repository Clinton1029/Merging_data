# %% [markdown]
# <a href="https://colab.research.google.com/github/Clinton1029/Merging_data/blob/main/Merging_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data1={
    "name": ["Amina", "Bramuel", "Cynthia", "Daniel", "Emily", "Felix", "Grace"],
    "id_no": ["1", "2", "3", "4", "5", "6", "7"],
    "age": [20, 22, 19, 23, 21, 24, 18],
    "weight": [55, 72, 60, 68, 59, 75, 53],
    "status": ["Active", "Inactive", "Active", "Active", "Suspended", "Active", "Inactive"]
}
df_studio = pd.DataFrame(data1)

df_studio.head(7)
# Out:
#       name id_no  age  weight     status
# 0    Amina     1   20      55     Active
# 1  Bramuel     2   22      72   Inactive
# 2  Cynthia     3   19      60     Active
# 3   Daniel     4   23      68     Active
# 4    Emily     5   21      59  Suspended
# 5    Felix     6   24      75     Active
# 6    Grace     7   18      53   Inactive

# %%
data1 ={
    "name": ["Amina", "Broly", "Nethan", "David", "Emily", "Felix", "Grace"],
    "reg_no": ["REG001", "REG002", "REG003", "REG004", "REG005", "REG006", "REG007"],
    "unit_3209": [78, 65, 82, 90, 74, 88, 69],
    "unit_3247": [81, 59, 76, 92, 70, 85, 63],
    "unit_3245": [69, 72, 80, 87, 66, 90, 71],
    "course": ["IT", "IT", "IT", "IT", "IT", "IT", "IT"]

}
df2 = pd.DataFrame(data1)

df_studio1 = pd.DataFrame(data1)

df_studio1
# Out:
#      name  reg_no  unit_3209  unit_3247  unit_3245 course
# 0   Amina  REG001         78         81         69     IT
# 1   Broly  REG002         65         59         72     IT
# 2  Nethan  REG003         82         76         80     IT
# 3   David  REG004         90         92         87     IT
# 4   Emily  REG005         74         70         66     IT
# 5   Felix  REG006         88         85         90     IT
# 6   Grace  REG007         69         63         71     IT

# %%
df_studio.head()
# Out:
#       name idno  age  weight     status
# 0    Amina    1   20      55     Active
# 1    Brian    2   22      72   Inactive
# 2  Cynthia    3   19      60     Active
# 3   Daniel    4   23      68     Active
# 4   Esther    5   21      59  Suspended

# %%
df_studio.tail()
# Out:
#       name idno  age  weight     status
# 2  Cynthia    3   19      60     Active
# 3   Daniel    4   23      68     Active
# 4   Esther    5   21      59  Suspended
# 5    Felix    6   24      75     Active
# 6    Grace    7   18      53   Inactive

# %%
print(df_studio.shape)
# Out:
# (7, 5)

# %%
print(df_studio.columns)
# Out:
# Index(['name', 'idno', 'age', 'weight', 'status'], dtype='object')

# %%
print(df_studio.dtypes)
# Out:
# name      object
# idno      object
# age        int64
# weight     int64
# status    object
# height     int64
# dtype: object

# %% [markdown]
# ## select Data

# %%
weight_col =df_studio['weight']
weight_col
# Out:
# 0    55
# 1    72
# 2    60
# 3    68
# 4    59
# 5    75
# 6    53
# Name: weight, dtype: int64

# %%
age_weg_col =df_studio[['age','weight']]
age_weg_col
# Out:
#    age  weight
# 0   20      55
# 1   22      72
# 2   19      60
# 3   23      68
# 4   21      59
# 5   24      75
# 6   18      53

# %%
first_row = df_studio.iloc[0]

# %%
filter =[df_studio['age']<20]
print(filter)
# Out:
# [0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# Name: age, dtype: bool]

# %% [markdown]
# ## Add remove columns

# %%
df_studio['height'] =[160,157,146,134,123,145,254]

# %%
df_studio_1 =df_studio.drop('idno',axis=1)
df_studio_1
# Out:
#       name  age  weight     status  height
# 0    Amina   20      55     Active     165
# 1    Brian   22      72   Inactive     157
# 2  Cynthia   19      60     Active     146
# 3   Daniel   23      68     Active     134
# 4   Esther   21      59  Suspended     123
# 5    Felix   24      75     Active     145
# 6    Grace   18      53   Inactive     254

# %% [markdown]
# ## Rename columns

# %%
df_studio_2 =df_studio.rename(columns={'age':'Age'})
df_studio_2
# Out:
#       name idno  Age  weight     status  height
# 0    Amina    1   20      55     Active     165
# 1    Brian    2   22      72   Inactive     157
# 2  Cynthia    3   19      60     Active     146
# 3   Daniel    4   23      68     Active     134
# 4   Esther    5   21      59  Suspended     123
# 5    Felix    6   24      75     Active     145
# 6    Grace    7   18      53   Inactive     254

# %% [markdown]
# ## Merging the df_studio AND df_studio1 Dataset

# %%
students_merged =pd.merge(df_studio,df_studio1
,on='name',how ='inner')

students_merged
# Out:
#      name idno  age  weight     status  reg_no  unit_3209  unit_3247  \
# 0   Amina    1   20      55     Active  REG001         78         81
# 1  Esther    5   21      59  Suspended  REG005         74         70
# 2   Felix    6   24      75     Active  REG006         88         85
# 3   Grace    7   18      53   Inactive  REG007         69         63
#
#    unit_3245 course
# 0         69     IT
# 1         66     IT
# 2         90     IT
# 3         71     IT
